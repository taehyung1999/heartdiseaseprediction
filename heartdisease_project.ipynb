# %% [markdown]
# ### Domain Analysis :
# 1.slope_of_peak_exercise_st_segment : The slope of the peak exercise ST segment, an electrocardiography read out indicating quality of blood flow to the heart. Flat, down sloping, or depressed ST segments may indicate "coronary ischemia", also called "Myocardial ischemia".1 : upsloping, 2: flat, 3: down sloping.• For instance, ST elevation with an upsloping ST segment is generally considered normal, while ST elevation with a horizontal ST segment is more characteristic of myocardial ischemia.The current Third Universal Definition of Myocardial Infarction document states that horizontal or downsloping ST depression is a sign of ischemia, whereas upsloping ST depression pattern is not specified as indicative of ischemia. A downsloping ST depression suggests the most extensive ischemia, while horizontal remains as the marker for a moderate process and an upsloping pattern indicates significant but smaller size.
#
# 2.thal : Thalassemia is an inherited blood disorder caused when the body doesn't make enough of a protein called hemoglobin, an important part of red blood cells. Results of thallium stress test measuring blood flow to the heart, with possible values normal, fixed_defect, reversible_defect. A normal result means blood flow through the coronary arteries is probably normal. 1: fixed defect (no blood flow in some part of the heart), 2: normal blood flow, 3: reversible defect (a blood flow is observed but it is not normal)
#
# 3.resting_blood_pressure : Usually, blood pressure starts to rise a few hours before a person wakes up. It continues to rise during the day, peaking in midday. Blood pressure typically drops in the late afternoon and evening. Blood pressure is usually lower at night while sleeping. Normal range for blood pressure is less than 120/80 millimeters of mercury (mmHg).
#
# 4.chest_pain_type : Angina is the term for chest pain caused by poor blood flow to the heart. Which is chest pain caused by blockages in the blood vessels leading to your heart. Typical angina - classic chest pain that is often described as pressure or squeezing, Atypical angina - chest pain with different or less typical symptoms, Non-anginal chest pain - chest pain not caused by angina, Asymptomatic - no chest pain or other symptoms present. 0: typical angina, 1: atypical angina, 2: non-anginal pain, 3: asymptomatic.
#
# 5.num_major_vessels : In the context of coronary angiography, the number of major vessels (0-3) refers to the number of coronary arteries with significant stenosis (narrowing) that are visualized during the exam. A value of 0 indicates that no major vessels are visualized, while a value of 3 indicates that all three major coronary arteries are visualized. The values in between represent the number of major vessels that are visualized. It's important to note that "fluoroscopy" is only one of the methods used to assess the number of major vessels, and the actual number may differ based on the method used and the specific patient and disease condition.
#
# 6.fasting_blood_sugar_gt_120_mg_per_dl : Fasting blood sugar greater than 120 mg/dl (yes / no). Normal fasting blood sugar levels for adults without diabetes are typically in the range of 70-99 mg/dL. However, individual levels may vary and a healthcare provider can provide specific guidance based on personal health and medical history. If blood sugar levels are consistently higher than 100 mg/dL while fasting, it may indicate prediabetes or diabetes and further evaluation by a healthcare provider is recommended.
#
# 7.resting_ekg_results : Resting electrocardiographic results (values 0,1,2). Value 0: normal, Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria. Nonspecific ST-segment and T-wave (ST-T) changes represent one of the most prevalent electrocardiographic abnormalities in hypertensive patients. Hypertrophy is the enlargement of an organ or tissue from the increase in size of its cells.
#
# 8.serum_cholesterol_mg_per_dl : Serum cholesterol is a type of fat (lipid) found in the blood. It is an essential component of cell membranes and is necessary for the production of hormones, bile acids, and vitamin D. However, high levels of cholesterol in the blood can increase the risk of heart disease and stroke. There are two main types of cholesterol: low-density lipoprotein (LDL) cholesterol and high-density lipoprotein (HDL) cholesterol. LDL cholesterol is often referred to as "bad" cholesterol because it can build up in the walls of the arteries, forming plaques that can narrow or block the arteries. This increases the risk of heart disease and stroke. On the other hand, HDL cholesterol is often referred to as "good" cholesterol because it helps remove excess cholesterol from the bloodstream and can help prevent the buildup of plaques in the arteries. The total cholesterol level in the blood is the sum of LDL cholesterol, HDL cholesterol, and other lipids. A healthy total cholesterol level is generally considered to be below 200 milligrams per deciliter (mg/dL), while a level above 240 mg/dL is considered high. To assess the risk of heart disease, healthcare providers typically consider not only the total cholesterol level, but also the levels of LDL cholesterol and HDL cholesterol and other factors, such as the patient's age, gender, family history, and lifestyle factors.
#
# 9.oldpeak_eq_st_depression : Oldpeak = ST depression induced by exercise relative to rest, a measure of abnormality in electrocardiograms. In the context of ECG and oldpeak/ST depression, a value greater than 4 millimeters (mm) can indicate significant myocardial ischemia, which is a reduced blood flow to the heart muscle. This can be a sign of underlying heart disease, such as coronary artery disease, and is generally considered to be a significant finding.
#
# 10.max_heart_rate_achieved : Maximum heart rate achieved (beats per minute). Maximum heart rate (MHR) is the highest number of beats per minute (bpm) that your heart can safely handle during physical activity. It is used to determine exercise intensity and help monitor progress.
# To interpret MHR, you can use the following formula:
# MHR = 220 – Age
# The resulting number is an estimate of your maximum heart rate, and can be used to determine your target heart rate zone for exercise. The target heart rate zone is usually between 50-85% of your MHR, which can help you get an optimal workout without overexerting yourself. A heart rate that exceeds your maximum heart rate (MHR) by a significant amount, or a heart rate that remains elevated even after physical activity has stopped, can indicate an underlying issue such as cardiovascular disease, heart attack, or an electrolyte imbalance. It is also important to note that heart rates that are consistently and significantly above your MHR can lead to overexertion and increased risk of injury.
#
# 11.exercise_induced_angina : • exercise-induced chest pain (0: False, 1: True). Exercise-induced chest pain can be a sign of a potential heart problem or another underlying health issue.
# Some common causes of exercise-induced chest pain include:
#
# Angina : Chest pain caused by reduced blood flow to the heart muscle.
# Coronary artery disease : Narrowing or blockage of the blood vessels that supply blood to the heart muscle.
# Aortic dissection : A tear in the inner wall of the aorta, the main blood vessel that carries blood away from the heart.
# Pulmonary embolism : A blockage in the lung's blood vessels, often due to a blood clot.
# Costochondritis : Inflammation of the cartilage that connects a rib to the breastbone.

# %% [markdown]
# ## Libraries we needed

# %%
#------------Basic Libraies------------------
import numpy as np, pandas as pd 
import matplotlib.pyplot as plt, seaborn as sns
import warnings
from sklearn import set_config

#-------------Some necessary configurations-----------------
warnings.filterwarnings("ignore")
# %matplotlib inline
set_config(display = "diagram")
pd.set_option("display.max_columns", None)
sns.set()

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#---------------Libraries for splitting the dataset, preprocessing and model creation--------------
from sklearn.model_selection import *
from sklearn.preprocessing import *

#---------Algorithms we needed to train our model------------
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

#-------------Balancing dataset-------------------
from imblearn.over_sampling import SMOTE # Oversampler
from imblearn.under_sampling import RandomUnderSampler # Undersampler

#-------------For prediction evaluation-----------------
from sklearn.metrics import *

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline

random_state = 100

# %%
#------------Fetching the file from the directory----------------------
import os

# Assuming 'newheartdisease' is a subdirectory in the current directory
directory_path = r'.\newheartdisease'

# Check if the directory exists
if os.path.exists(directory_path) and os.path.isdir(directory_path):
    # List contents of the directory
    for dirname, _, filenames in os.walk(directory_path):
        for filename in filenames:
            print(os.path.join(dirname, filename))
else:
    print("Directory does not exist or is not a valid directory.")
# Out:
# .\newheartdisease\labels.csv
# .\newheartdisease\values.csv

# %%
df_1 = pd.read_csv(r".\newheartdisease\values.csv")
df_2 = pd.read_csv(r".\newheartdisease\labels.csv")

# %% [markdown]
# ## Merging features columns and target columns and dropping "pateint_id" column

# %%
X = pd.concat([df_1, df_2], axis=1)
X.drop(["patient_id"], axis = 1, inplace = True)

# %%
print(f"Columns : \n{list(X.columns)}")
print(f"Total Columns : {len(list(X.columns))}")
# Out:
# Columns :
# ['slope_of_peak_exercise_st_segment', 'thal', 'resting_blood_pressure', 'chest_pain_type', 'num_major_vessels', 'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results', 'serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age', 'max_heart_rate_achieved', 'exercise_induced_angina', 'heart_disease_present']
# Total Columns : 14

# %% [markdown]
# ## Columns of the dataset :
# There are 14 columns in the dataset, where the patient_id column is a unique and random identifier. The remaining 13 features are described in the section below.
# 1.slope_of_peak_exercise_st_segment (type: int): the slope of the peak exercise ST segment, an electrocardiography read out indicating quality of blood flow to the heart
# 2.thal (type: categorical): results of thallium stress test measuring blood flow to the heart, with possible values normal, fixed_defect, reversible_defect
# 3.resting_blood_pressure (type: int): resting blood pressure
# 4.chest_pain_type (type: int): chest pain type (4 values)
# 5.num_major_vessels (type: int): number of major vessels (0-3) colored by flourosopy
# 6.fasting_blood_sugar_gt_120_mg_per_dl (type: binary): fasting blood sugar > 120 mg/dl
# 7.resting_ekg_results (type: int): resting electrocardiographic results (values 0,1,2)
# 8.serum_cholesterol_mg_per_dl (type: int): serum cholestoral in mg/dl
# 9.oldpeak_eq_st_depression (type: float): oldpeak = ST depression induced by exercise relative to rest, a measure of abnormality in electrocardiograms
# 10.sex (type: binary): 0: female, 1: male
# 11.age (type: int): age in years
# 12.max_heart_rate_achieved (type: int): maximum heart rate achieved (beats per minute)
# 13.exercise_induced_angina (type: binary): exercise-induced chest pain (0: False, 1: True)### Columns of the dataset :

# %% [markdown]
# ## Basic Checks :

# %% [markdown]
# ### Shape of the dataset :

# %%
print(f"Rows : {X.shape[0]}\nColumns : {X.shape[1]}")
# Out:
# Rows : 180
# Columns : 14

# %%
X.head()
# Out:
#    slope_of_peak_exercise_st_segment               thal  \
# 0                                  1             normal
# 1                                  2             normal
# 2                                  1             normal
# 3                                  1  reversible_defect
# 4                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# 2                                     0                    2
# ...

# %%
X.tail()
# Out:
#      slope_of_peak_exercise_st_segment               thal  \
# 175                                  2  reversible_defect
# 176                                  2             normal
# 177                                  2  reversible_defect
# 178                                  1             normal
# 179                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 175                     125                4                  2
# 176                     180                4                  0
# 177                     125                3                  0
# 178                     124                3                  2
# 179                     160                3                  1
#
#      fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 175                                     1                    0
# 176                                     0                    1
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   slope_of_peak_exercise_st_segment     180 non-null    int64
#  1   thal                                  180 non-null    object
#  2   resting_blood_pressure                180 non-null    int64
#  3   chest_pain_type                       180 non-null    int64
#  4   num_major_vessels                     180 non-null    int64
#  5   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  6   resting_ekg_results                   180 non-null    int64
#  7   serum_cholesterol_mg_per_dl           180 non-null    int64
#  8   oldpeak_eq_st_depression              180 non-null    float64
#  9   sex                                   180 non-null    int64
#  10  age                                   180 non-null    int64
# ...

# %% [markdown]
# ##### ** Here, "thal" is a object type, we will take care of this feature by using encoding

# %% [markdown]
# #### Statistical Descriptions of numerical columns (here we have Price) :

# %%
X.describe().T
# Out:
#                                       count        mean        std    min  \
# slope_of_peak_exercise_st_segment     180.0    1.550000   0.618838    1.0
# resting_blood_pressure                180.0  131.311111  17.010443   94.0
# chest_pain_type                       180.0    3.155556   0.938454    1.0
# num_major_vessels                     180.0    0.694444   0.969347    0.0
# fasting_blood_sugar_gt_120_mg_per_dl  180.0    0.161111   0.368659    0.0
# resting_ekg_results                   180.0    1.050000   0.998742    0.0
# serum_cholesterol_mg_per_dl           180.0  249.211111  52.717969  126.0
# oldpeak_eq_st_depression              180.0    1.010000   1.121357    0.0
# sex                                   180.0    0.688889   0.464239    0.0
# age                                   180.0   54.811111   9.334737   29.0
# max_heart_rate_achieved               180.0  149.483333  22.063513   96.0
# exercise_induced_angina               180.0    0.316667   0.466474    0.0
# ...

# %%
# Checking of missing values :
X.isnull().sum()
# Out:
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# resting_blood_pressure                  0
# chest_pain_type                         0
# num_major_vessels                       0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# oldpeak_eq_st_depression                0
# sex                                     0
# age                                     0
# max_heart_rate_achieved                 0
# exercise_induced_angina                 0
# heart_disease_present                   0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
X["slope_of_peak_exercise_st_segment"].value_counts()
# Out:
# slope_of_peak_exercise_st_segment
# 1    93
# 2    75
# 3    12
# Name: count, dtype: int64

# %%
sns.countplot(x = X["slope_of_peak_exercise_st_segment"], hue = X["heart_disease_present"])
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# #### 1 --> Upsloping, 2 --> Flat, 3 --> Downsloping

# %% [markdown]
# For upsloping, chances of heart disease is less compared to other categories.
# Flat and downsloping has the maximum chances to have heart disease.

# %%
# Reshape the DataFrame into long-form
melted_df = pd.melt(X, id_vars=["thal"], value_vars=["heart_disease_present"])

# Create the countplot with the reshaped DataFrame
sns.countplot(data=melted_df, x="thal", hue="value")

# Display the legend
plt.legend(title="heart_disease_present")

# Show the plot
plt.show()

# %% [markdown]
# Having normal blood flow results in less chances to have heart disease compared to other categories.
# Reversible defect has the highest chance of having heart disease.

# %% [markdown]
# sns.countplot(X["chest_pain_type"], hue = X["heart_disease_present"])
# plt.legend(loc = "best", title = "heart_disease_present")
# plt.show()

# %%
# Reshape the DataFrame into long-form
melted_df = pd.melt(X, id_vars=["chest_pain_type"], value_vars=["heart_disease_present"])

# Create the countplot with the reshaped DataFrame
sns.countplot(data=melted_df, x="chest_pain_type", hue="value")

# Display the legend
plt.legend(title="heart_disease_present")

# Show the plot
plt.show()

# %% [markdown]
# Asymptomatic(4) has the highest chances of getting heart disease.
# Non-anginal chest pain (3), Atypical angina (2) and Typical angina (1) are having less frequncies of getting heart disease.

# %%
plt.figure(figsize = (17,4))
plt.subplot(1,2,1)
sns.distplot(X["resting_blood_pressure"])
plt.title("Distribution Plot")
plt.subplot(1,2,2)
sns.boxplot(X["resting_blood_pressure"])
plt.title("Box Plot")
plt.show()

# %% [markdown]
# A normal resting blood pressure for an adult is around 120/80 mmHg.
# A blood pressure reading above 140/90 mmHg is considered high.
# A reading above 160/100 mmHg is considered stage 2 hypertension, which is a serious condition and requires medical attention.
# A reading above 180/120 mmHg is considered a hypertensive crisis, which is a medical emergency requiring prompt treatment.
# ##### **Hence we are not going to remove the outliers. No, readings above 160/100 mmHg cannot be treated as outliers as they indicate stage 2 hypertension, which is a significant health concern. They require medical evaluation and treatment to lower the blood pressure and reduce the risk of associated health problems such as stroke, heart disease, and kidney disease.

# %%
# Reshape the DataFrame into long-form
melted_df = pd.melt(X, id_vars=["num_major_vessels"], value_vars=["heart_disease_present"])

# Create the countplot with the reshaped DataFrame
sns.countplot(data=melted_df, x="num_major_vessels", hue="value")

# Display the legend
plt.legend(title="heart_disease_present")

# Show the plot
plt.show()

# %% [markdown]
# The number of coronary vessels affected by fatty deposits (atherosclerosis) can impact the likelihood of developing heart disease. If more vessels are affected, it can increase the risk of heart disease and potentially lead to a heart attack.
# As the num_major_vessels is 0, hence the chances of getting heart disease is also less.

# %%
# Reshape the DataFrame into long-form
melted_df = pd.melt(X, id_vars=["fasting_blood_sugar_gt_120_mg_per_dl"], value_vars=["heart_disease_present"])

# Create the countplot with the reshaped DataFrame
sns.countplot(data=melted_df, x="fasting_blood_sugar_gt_120_mg_per_dl", hue="value")

# Display the legend
plt.legend(title="heart_disease_present")

# Show the plot
plt.show()

# %% [markdown]
# Those who have blood sugar less than 120 mg/dl are having less chances of getting heart disease.
# Normal fasting blood sugar levels for adults without diabetes are typically in the range of 70-99 mg/dL.
# If blood sugar levels are consistently higher than 100 mg/dL while fasting, it may indicate prediabetes or diabetes and further evaluation by a healthcare provider is recommended.

# %%
# Reshape the DataFrame into long-form
melted_df = pd.melt(X, id_vars=["resting_ekg_results"], value_vars=["heart_disease_present"])

# Create the countplot with the reshaped DataFrame
sns.countplot(data=melted_df, x="resting_ekg_results", hue="value")

# Display the legend
plt.legend(title="heart_disease_present")

# Show the plot
plt.show()

# %% [markdown]
# In Resting electrocardiographic whose result is normal(0) are having less chances of getting heart disease.
# "Having ST-T(1)" shows there is a chance of having disease.
# "Hypertrophy(2)" shows both the chances.
# Hypertrophy : the enlargement of an organ or tissue from the increase in size of its cells.

# %%
plt.figure(figsize = (17,4))
plt.subplot(1,2,1)
sns.distplot(X["serum_cholesterol_mg_per_dl"])
plt.title("Distribution Plot")
plt.subplot(1,2,2)
sns.boxplot(X["serum_cholesterol_mg_per_dl"])
plt.title("Box Plot")
plt.show()

# %% [markdown]
# The average range for total serum cholesterol is typically considered to be between 130-240 mg/dL. However, optimal levels may vary depending on individual factors such as age, gender, and health status.
# Values above 240 mg/dL are generally considered elevated and may indicate an increased risk for cardiovascular disease.
# Values over 400 mg/dL are considered very high and may indicate a serious health condition such as familial hypercholesterolemia. People with such high cholesterol levels are at increased risk for cardiovascular disease and require prompt medical attention and treatment.
# Values over 400 mg/dL are not considered outliers but rather indicate a serious health condition that requires prompt medical attention and treatment.
# ##### **Hence we are not going to remove the outliers.

# %%
plt.figure(figsize = (17,4))
plt.subplot(1,2,1)
sns.distplot(X["oldpeak_eq_st_depression"])
plt.title("Distribution Plot")
plt.subplot(1,2,2)
sns.boxplot(X["oldpeak_eq_st_depression"])
plt.title("Box Plot")
plt.show()

# %% [markdown]
# In the context of ECG and oldpeak/ST depression, a value greater than 4 millimeters (mm) can indicate significant myocardial ischemia, which is a reduced blood flow to the heart muscle. This can be a sign of underlying heart disease, such as coronary artery disease.
# An ST depression of greater than 4 mm is generally considered to be significant and may indicate a high-risk cardiac event such as a heart attack.
# It is possible for the ST depression to be greater than 6 mm on an electrocardiogram (ECG). However, such a high level of ST depression is uncommon and may indicate a severe cardiac event such as a large heart attack.

# %%
# Reshape the DataFrame into long-form
melted_df = pd.melt(X, id_vars=["sex"], value_vars=["heart_disease_present"])

# Create the countplot with the reshaped DataFrame
sns.countplot(data=melted_df, x="sex", hue="value")

# Display the legend
plt.legend(title="heart_disease_present")

# Show the plot
plt.show()

# %% [markdown]
# 0: female, 1: male
# Female has the less chance of getting heart disease compared to Male.

# %%
plt.figure(figsize = (17,4))
plt.subplot(1,2,1)
sns.distplot(X["age"])
plt.title("Distribution Plot")
plt.subplot(1,2,2)
sns.boxplot(X["age"])
plt.title("Box Plot")
plt.show()

# %% [markdown]
# Age is almost normally distributed, having no outliers.

# %%
plt.figure(figsize = (17,4))
plt.subplot(1,2,1)
sns.distplot(X["max_heart_rate_achieved"])
plt.title("Distribution Plot")
plt.subplot(1,2,2)
sns.boxplot(X["max_heart_rate_achieved"])
plt.title("Box Plot")
plt.show()

# %% [markdown]
# Max heart rate is almost normally distributed, having no outliers. It has higest occurence at 160.

# %%
# Reshape the DataFrame into long-form
melted_df = pd.melt(X, id_vars=["exercise_induced_angina"], value_vars=["heart_disease_present"])

# Create the countplot with the reshaped DataFrame
sns.countplot(data=melted_df, x="exercise_induced_angina", hue="value")

# Display the legend
plt.legend(title="heart_disease_present")

# Show the plot
plt.show()

# %% [markdown]
# Exercise-induced chest pain (0: False, 1: True).
# Those values are false means they are having less chances of getting heart disease.

# %%
num_cols = ['slope_of_peak_exercise_st_segment','resting_blood_pressure', 'chest_pain_type', 'num_major_vessels',
              'fasting_blood_sugar_gt_120_mg_per_dl', 'resting_ekg_results','serum_cholesterol_mg_per_dl', 'oldpeak_eq_st_depression', 'sex', 'age',
              'max_heart_rate_achieved', 'exercise_induced_angina']
plt.figure(figsize = (17,7))
sns.heatmap(X[num_cols].corr(), annot = True, cmap = "PiYG")
plt.show()

# %% [markdown]
# ##### None of the columns have high correlation between them.

# %% [markdown]
# ### Splitting the dataset into training and testing set

# %%
X_new = X.iloc[:, :-1]
y_new = X["heart_disease_present"]

# %%
X_train, X_test, y_train, y_test =  train_test_split(X_new, y_new, test_size = 0.2, random_state = random_state)

# %%
X_train.shape, X_test.shape
# Out:
# ((144, 13), (36, 13))

# %% [markdown]
# ### Some data preprocessing with ColumnTransformer and Pipeline

# %%
## Making separate transformers for OneHotEncoder and StandardScaler,

transformer_1 = ColumnTransformer([
    ("thal", OneHotEncoder(sparse = False, drop = "first", dtype = np.float32), [1]),
], remainder = "passthrough")

transformer_2 = ColumnTransformer([
    ("trf_2", StandardScaler(), slice(0,14))
], remainder = "passthrough")

# %% [markdown]
# #### Merging two transformers in a single pipeline

# %%
pipe_1 = Pipeline([
    ("p_1", transformer_1),
    ("p_2", transformer_2)
])

# %% [markdown]
# ##### Diagram of the pipeline

# %%
pipe_1
# Out:
# Pipeline(steps=[('p_1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('thal',
#                                                   OneHotEncoder(drop='first',
#                                                                 dtype=<class 'numpy.float32'>,
#                                                                 sparse=False),
#                                                   [1])])),
#                 ('p_2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf_2', StandardScaler(),
#                                                   slice(0, 14, None))]))])

# %% [markdown]
# #### Transforming the X_train and X_test

# %%
X_train_transformed = pipe_1.fit_transform(X_train)
X_test_transformed = pipe_1.transform(X_test)

# %% [markdown]
# ## Some Important User Defined Functions:

# %% [markdown]
# ### 1. Cross val score

# %%
def UserCrossValScores(estimator, X, y, cv = None, n_jobs = -1, scoring = "accuracy"):
    if cv == None:
        cv = 5
    scores = cross_val_score(estimator = estimator, X = X, y = y, cv = cv, n_jobs = n_jobs, scoring = scoring)
    print(f"Scores : {scores}")
    print(f"Mean score : {np.mean(scores)}")
    print(f"Standard Dev. : {np.std(scores)}")

# %% [markdown]
# ### 2. Learning Curve

# %%
def UserLearningCurve(estimator, X, y, label,train_size = np.linspace(0.1, 1, 5), cv = None, n_jobs = -1, scoring = "accuracy"):
    if cv == None:
        cv = 5
    train_sizes, train_scores, validation_scores = learning_curve(estimator = estimator, 
                                                                  X = X, y = y, train_sizes = train_size, cv = cv, scoring = scoring, n_jobs = n_jobs)
    mean_train_score = np.mean(train_scores, axis = 1)
    mean_validation_score = np.mean(validation_scores, axis = 1)
    
    plt.plot(train_sizes, mean_train_score, label = "Training", marker = "o")
    plt.plot(train_sizes, mean_validation_score, label = "Validation", color = "g", marker = "o")
    plt.title(f"Learning curve for {label}")
    plt.xlabel("No. of train sizes")
    plt.ylabel(f"{scoring.capitalize()}")
    plt.legend(loc = "best")

# %% [markdown]
# ### 3. ROC_AUC

# %%
def UserRocAuc(y_true, y_prob, label = ""):
    fpr, tpr, thresholds = roc_curve(y_true, y_prob[:, 1])
    #auc_score = auc(fpr, tpr)
    auc_score = roc_auc_score(y_true, y_prob[:, 1])
    
    plt.plot(fpr, tpr, label = f"{label}(AUC = {round(auc_score, 5)})")
    
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve")
    
    plt.legend(loc = "best")

# %% [markdown]
# ### 4. Grid Search CV

# %%
def UserGridSearchCV(model, params, X, y, cv = None, n_jobs = -1, scoring = "accuracy"):
    if cv == None:
        cv = 5
    grid_cv = GridSearchCV(estimator = model, param_grid = params, cv = cv, scoring = scoring, n_jobs = n_jobs)
    
    grid_cv.fit(X, y)
    
    print(f"Best Params : {grid_cv.best_params_}")
    print(f"Best Score : {grid_cv.best_score_}")
    print(f"Best Estimator : {grid_cv.best_estimator_}")
    
    return grid_cv.best_estimator_

# %% [markdown]
# ### 5. Metric Evaluation

# %%
def UserMetric(y_true, y_pred, label):
    print(f"{label}:")
    print(f"Accuracy : {accuracy_score(y_true, y_pred)}")
    print(f"Precision : {precision_score(y_true, y_pred)}")
    print(f"Recall : {recall_score(y_true, y_pred)}")
    print(f"{classification_report(y_true, y_pred)}")
    print(f"Confusion Matrix : {confusion_matrix(y_true, y_pred).ravel()}")
    print("--"*40)

# %% [markdown]
# ##### Checking the y_train classes, if balanced or not

# %%
y_train.value_counts()
# Out:
# heart_disease_present
# 0    80
# 1    64
# Name: count, dtype: int64

# %% [markdown]
# Here we can observe that classes in y_train are imbalanced, so we will apply both over sampling and under sampling techniques.

# %% [markdown]
# ### Balancing the data:

# %%
smote = SMOTE() # oversampler
rus = RandomUnderSampler() # undersampler

X_smote, y_smote = smote.fit_resample(X_train_transformed, y_train)
X_rus, y_rus = rus.fit_resample(X_train_transformed, y_train)

# %%
print("Oversampling:")
print(y_smote.value_counts())
print("*"*50)
print("Undersampling:")
print(y_rus.value_counts())
# Out:
# Oversampling:
# heart_disease_present
# 0    80
# 1    80
# Name: count, dtype: int64
# **************************************************
# Undersampling:
# heart_disease_present
# 0    64
# 1    64
# Name: count, dtype: int64

# %% [markdown]
# ## Model Creation

# %% [markdown]
# #### 1. LogisticRegression

# %%
log_reg_1 = LogisticRegression()
log_reg_1.fit(X_train_transformed, y_train)

log_reg_2 = LogisticRegression()
log_reg_2.fit(X_smote, y_smote)

log_reg_3 = LogisticRegression()
log_reg_3.fit(X_rus, y_rus)
# Out:
# LogisticRegression()

# %%
y_pred_train_1 = log_reg_1.predict(X_train_transformed)
y_pred_test_1 = log_reg_1.predict(X_test_transformed)
y_pred_proba_1 = log_reg_1.predict_proba(X_test_transformed)

y_pred_train_2 = log_reg_2.predict(X_smote)
y_pred_test_2 = log_reg_2.predict(X_test_transformed)
y_pred_proba_2 = log_reg_2.predict_proba(X_test_transformed)

y_pred_train_3 = log_reg_3.predict(X_rus)
y_pred_test_3 = log_reg_3.predict(X_test_transformed)
y_pred_proba_3 = log_reg_3.predict_proba(X_test_transformed)

# %%
# Imbalanced:
UserMetric(y_train, y_pred_train_1, label = "Train")
UserMetric(y_test, y_pred_test_1, label = "Test")
# Out:
# Train:
# Accuracy : 0.8333333333333334
# Precision : 0.8225806451612904
# Recall : 0.796875
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        80
#            1       0.82      0.80      0.81        64
#
#     accuracy                           0.83       144
#    macro avg       0.83      0.83      0.83       144
# weighted avg       0.83      0.83      0.83       144
#
# Confusion Matrix : [69 11 13 51]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8888888888888888
# Precision : 0.9285714285714286
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        20
#            1       0.93      0.81      0.87        16
#
#     accuracy                           0.89        36
#    macro avg       0.90      0.88      0.89        36
# weighted avg       0.89      0.89      0.89        36
#
# ...

# %%
# cross val score:
UserCrossValScores(log_reg_1, X_train_transformed, y_train, scoring = "recall")
# Out:
# Scores : [0.53846154 0.76923077 0.84615385 0.92307692 0.75      ]
# Mean score : 0.7653846153846153
# Standard Dev. : 0.12894657395569395

# %%
# Oversampling:
UserMetric(y_smote, y_pred_train_2, label = "Train")
UserMetric(y_test, y_pred_test_2, label = "Test")
# Out:
# Train:
# Accuracy : 0.8625
# Precision : 0.8717948717948718
# Recall : 0.85
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        80
#            1       0.87      0.85      0.86        80
#
#     accuracy                           0.86       160
#    macro avg       0.86      0.86      0.86       160
# weighted avg       0.86      0.86      0.86       160
#
# Confusion Matrix : [70 10 12 68]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8888888888888888
# Precision : 0.9285714285714286
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        20
#            1       0.93      0.81      0.87        16
#
#     accuracy                           0.89        36
#    macro avg       0.90      0.88      0.89        36
# weighted avg       0.89      0.89      0.89        36
#
# ...

# %%
# cross val score:
UserCrossValScores(log_reg_2, X_smote, y_smote, scoring = "recall")
# Out:
# Scores : [0.625  0.875  0.875  0.8125 0.875 ]
# Mean score : 0.8125
# Standard Dev. : 0.09682458365518543

# %%
# Undersampling:
UserMetric(y_rus, y_pred_train_3, label = "Train")
UserMetric(y_test, y_pred_test_3, label = "Test")
# Out:
# Train:
# Accuracy : 0.84375
# Precision : 0.8666666666666667
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85        64
#            1       0.87      0.81      0.84        64
#
#     accuracy                           0.84       128
#    macro avg       0.85      0.84      0.84       128
# weighted avg       0.85      0.84      0.84       128
#
# Confusion Matrix : [56  8 12 52]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8888888888888888
# Precision : 0.9285714285714286
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        20
#            1       0.93      0.81      0.87        16
#
#     accuracy                           0.89        36
#    macro avg       0.90      0.88      0.89        36
# weighted avg       0.89      0.89      0.89        36
#
# ...

# %%
# cross val score:
UserCrossValScores(log_reg_3, X_rus, y_rus, scoring = "recall")
# Out:
# Scores : [0.61538462 0.76923077 0.92307692 1.         0.76923077]
# Mean score : 0.8153846153846154
# Standard Dev. : 0.13411996749355917

# %%
# Ploting Learning Curve:
plt.figure(figsize = (19, 13))

plt.subplot(2, 2, 1)
UserLearningCurve(log_reg_1, X_train_transformed, y_train, label = "Imbalanced",scoring = "recall")
plt.subplot(2, 2, 2)
UserLearningCurve(log_reg_2, X_smote, y_smote, label = "SMOTE", scoring = "recall")
plt.subplot(2, 2, 3)
UserLearningCurve(log_reg_3, X_rus, y_rus, label = "RUS", scoring = "recall")

# %%
# Ploting ROC AUC:
plt.figure(figsize = (10, 6))
plt.plot([0,1], [0,1], "--",label = "Baseline")
UserRocAuc(y_test, y_pred_proba_1, label = "Imbalanced")
UserRocAuc(y_test, y_pred_proba_2, label = "SMOTE")
UserRocAuc(y_test, y_pred_proba_3, label = "RUS")

# %% [markdown]
# ### RESULT 1:
# #### From the above scores, ROC curves and AUC values, LogisticRegression with RandomUnderSampler is giving higher AUC score than other sampling techniques. ROC curve for RandomUnderSampler is covering more area.

# %% [markdown]
# ## 2. KNN

# %%
# Finding the optimal k values for imbalanced, over sampler and under sampler
Error_1 = [] # Imbalanced Error
Error_2 = [] # Oversampler Error
Error_3 = [] # Undersampler Error
for k in range(1,14):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_transformed, y_train)
    y_pred = knn.predict(X_test_transformed)
    Error_1.append(np.mean(y_test != y_pred))
    
    knn_1 = KNeighborsClassifier(n_neighbors=k)
    knn_1.fit(X_smote, y_smote)
    y_pred_1 = knn_1.predict(X_test_transformed)
    Error_2.append(np.mean(y_test != y_pred_1))
    
    knn_2 = KNeighborsClassifier(n_neighbors=k)
    knn_2.fit(X_rus, y_rus)
    y_pred_2 = knn_2.predict(X_test_transformed)
    Error_3.append(np.mean(y_test != y_pred_2))

# %%
plt.figure(figsize = (20, 10))

plt.subplot(2,2,1)
plt.plot(range(1, 14), Error_1, marker = "o")
plt.title("Imbalanced")
plt.subplot(2,2,2)
plt.plot(range(1, 14), Error_2, marker = "o", color = "g")
plt.title("SMOTE")
plt.subplot(2,2,3)
plt.plot(range(1, 14), Error_3, marker = "o", color = "r")
plt.title("RUS")

plt.show()

# %% [markdown]
# #### From the plots we get,
#
# Imbalanced : k = 9
# SMOTE : k = 11
# RUS : k = 9

# %%
knn_1 = KNeighborsClassifier(n_neighbors=9)
knn_1.fit(X_train_transformed, y_train)

knn_2 = KNeighborsClassifier(n_neighbors=11)
knn_2.fit(X_smote, y_smote)

knn_3 = KNeighborsClassifier(n_neighbors=9)
knn_3.fit(X_rus, y_rus)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred_train_knn_1 = knn_1.predict(X_train_transformed)
y_pred_test_knn_1 = knn_1.predict(X_test_transformed)
y_pred_proba_knn_1 = knn_1.predict_proba(X_test_transformed)

y_pred_train_knn_2 = knn_2.predict(X_smote)
y_pred_test_knn_2 = knn_2.predict(X_test_transformed)
y_pred_proba_knn_2 = knn_2.predict_proba(X_test_transformed)

y_pred_train_knn_3 = knn_3.predict(X_rus)
y_pred_test_knn_3 = knn_3.predict(X_test_transformed)
y_pred_proba_knn_3 = knn_3.predict_proba(X_test_transformed)

# %%
# Imbalanced:
UserMetric(y_train, y_pred_train_knn_1, label = "Train")
UserMetric(y_test, y_pred_test_knn_1, label = "Test")
# Out:
# Train:
# Accuracy : 0.8333333333333334
# Precision : 0.8225806451612904
# Recall : 0.796875
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        80
#            1       0.82      0.80      0.81        64
#
#     accuracy                           0.83       144
#    macro avg       0.83      0.83      0.83       144
# weighted avg       0.83      0.83      0.83       144
#
# Confusion Matrix : [69 11 13 51]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.9166666666666666
# Precision : 1.0
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        20
#            1       1.00      0.81      0.90        16
#
#     accuracy                           0.92        36
#    macro avg       0.93      0.91      0.91        36
# weighted avg       0.93      0.92      0.92        36
#
# ...

# %%
# cross val score:
UserCrossValScores(knn_1, X_train_transformed, y_train, scoring = "recall")
# Out:
# Scores : [0.38461538 0.84615385 0.92307692 0.92307692 0.83333333]
# Mean score : 0.7820512820512822
# Standard Dev. : 0.2022230169551831

# %%
# Oversampling:
UserMetric(y_smote, y_pred_train_knn_2, label = "Train")
UserMetric(y_test, y_pred_test_knn_2, label = "Test")
# Out:
# Train:
# Accuracy : 0.81875
# Precision : 0.8072289156626506
# Recall : 0.8375
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82        80
#            1       0.81      0.84      0.82        80
#
#     accuracy                           0.82       160
#    macro avg       0.82      0.82      0.82       160
# weighted avg       0.82      0.82      0.82       160
#
# Confusion Matrix : [64 16 13 67]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8611111111111112
# Precision : 0.8666666666666667
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        20
#            1       0.87      0.81      0.84        16
#
#     accuracy                           0.86        36
#    macro avg       0.86      0.86      0.86        36
# weighted avg       0.86      0.86      0.86        36
#
# ...

# %%
# cross val score:
UserCrossValScores(knn_2, X_smote, y_smote, scoring = "recall")
# Out:
# Scores : [0.5    0.9375 0.9375 0.875  0.9375]
# Mean score : 0.8375
# Standard Dev. : 0.1704772712123232

# %%
# Undersampling:
UserMetric(y_rus, y_pred_train_knn_3, label = "Train")
UserMetric(y_test, y_pred_test_knn_3, label = "Test")
# Out:
# Train:
# Accuracy : 0.8203125
# Precision : 0.8360655737704918
# Recall : 0.796875
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82        64
#            1       0.84      0.80      0.82        64
#
#     accuracy                           0.82       128
#    macro avg       0.82      0.82      0.82       128
# weighted avg       0.82      0.82      0.82       128
#
# Confusion Matrix : [54 10 13 51]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.9166666666666666
# Precision : 1.0
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        20
#            1       1.00      0.81      0.90        16
#
#     accuracy                           0.92        36
#    macro avg       0.93      0.91      0.91        36
# weighted avg       0.93      0.92      0.92        36
#
# Confusion Matrix : [20  0  3 13]
# ...

# %%
# cross val score:
UserCrossValScores(knn_3, X_rus, y_rus, scoring = "recall")
# Out:
# Scores : [0.46153846 0.76923077 0.92307692 1.         0.84615385]
# Mean score : 0.8
# Standard Dev. : 0.185893014978378

# %%
# Ploting Learning Curve:
plt.figure(figsize = (19, 13))

plt.subplot(2, 2, 1)
UserLearningCurve(knn_1, X_train_transformed, y_train, label = "Imbalanced",scoring = "recall")
plt.subplot(2, 2, 2)
UserLearningCurve(knn_2, X_smote, y_smote, label = "SMOTE", scoring = "recall")
plt.subplot(2, 2, 3)
UserLearningCurve(knn_3, X_rus, y_rus, label = "RUS", scoring = "recall")

# %%
# Ploting ROC AUC:
plt.figure(figsize = (10, 6))
plt.plot([0,1], [0,1], "--",label = "Baseline")
UserRocAuc(y_test, y_pred_proba_knn_1, label = "Imbalanced")
UserRocAuc(y_test, y_pred_proba_knn_2, label = "SMOTE")
UserRocAuc(y_test, y_pred_proba_knn_3, label = "RUS")

# %% [markdown]
# #### RESULT 2:
# ##### From the above scores, ROC curves and AUC values, KNN with RandomUnderSampler is giving slightly higher AUC score than imbalanced one. ROC curve for RandomUnderSampler is covering more area.

# %% [markdown]
# ### 3. SVM

# %%
svm_1 = SVC(probability = True)
svm_1.fit(X_train_transformed, y_train)

svm_2 = SVC(probability = True)
svm_2.fit(X_smote, y_smote)

svm_3 = SVC(probability = True)
svm_3.fit(X_rus, y_rus)
# Out:
# SVC(probability=True)

# %%
y_pred_train_svm_1 = svm_1.predict(X_train_transformed)
y_pred_test_svm_1 = svm_1.predict(X_test_transformed)
y_pred_proba_svm_1 = svm_1.predict_proba(X_test_transformed)

y_pred_train_svm_2 = svm_2.predict(X_smote)
y_pred_test_svm_2 = svm_2.predict(X_test_transformed)
y_pred_proba_svm_2 = svm_2.predict_proba(X_test_transformed)

y_pred_train_svm_3 = svm_3.predict(X_rus)
y_pred_test_svm_3 = svm_3.predict(X_test_transformed)
y_pred_proba_svm_3 = svm_3.predict_proba(X_test_transformed)

# %%
# Imbalanced:
UserMetric(y_train, y_pred_train_svm_1, label = "Train")
UserMetric(y_test, y_pred_test_svm_1, label = "Test")
# Out:
# Train:
# Accuracy : 0.8958333333333334
# Precision : 0.9152542372881356
# Recall : 0.84375
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        80
#            1       0.92      0.84      0.88        64
#
#     accuracy                           0.90       144
#    macro avg       0.90      0.89      0.89       144
# weighted avg       0.90      0.90      0.90       144
#
# Confusion Matrix : [75  5 10 54]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8611111111111112
# Precision : 0.9230769230769231
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88        20
#            1       0.92      0.75      0.83        16
#
#     accuracy                           0.86        36
#    macro avg       0.87      0.85      0.86        36
# weighted avg       0.87      0.86      0.86        36
#
# ...

# %%
# cross val score:
UserCrossValScores(svm_1, X_train_transformed, y_train, scoring = "recall")
# Out:
# Scores : [0.38461538 0.84615385 0.76923077 0.84615385 0.91666667]
# Mean score : 0.7525641025641026
# Standard Dev. : 0.18979555767894413

# %%
# Oversampling:
UserMetric(y_smote, y_pred_train_svm_2, label = "Train")
UserMetric(y_test, y_pred_test_svm_2, label = "Test")
# Out:
# Train:
# Accuracy : 0.91875
# Precision : 0.935064935064935
# Recall : 0.9
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        80
#            1       0.94      0.90      0.92        80
#
#     accuracy                           0.92       160
#    macro avg       0.92      0.92      0.92       160
# weighted avg       0.92      0.92      0.92       160
#
# Confusion Matrix : [75  5  8 72]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.8571428571428571
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86        20
#            1       0.86      0.75      0.80        16
#
#     accuracy                           0.83        36
#    macro avg       0.84      0.82      0.83        36
# weighted avg       0.84      0.83      0.83        36
#
# ...

# %%
# cross val score:
UserCrossValScores(svm_2, X_smote, y_smote, scoring = "recall")
# Out:
# Scores : [0.4375 0.9375 0.9375 0.875  0.9375]
# Mean score : 0.825
# Standard Dev. : 0.19525624189766635

# %%
# Undersampling:
UserMetric(y_rus, y_pred_train_svm_3, label = "Train")
UserMetric(y_test, y_pred_test_svm_3, label = "Test")
# Out:
# Train:
# Accuracy : 0.8984375
# Precision : 0.9180327868852459
# Recall : 0.875
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        64
#            1       0.92      0.88      0.90        64
#
#     accuracy                           0.90       128
#    macro avg       0.90      0.90      0.90       128
# weighted avg       0.90      0.90      0.90       128
#
# Confusion Matrix : [59  5  8 56]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.7777777777777778
# Precision : 0.75
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        20
#            1       0.75      0.75      0.75        16
#
#     accuracy                           0.78        36
#    macro avg       0.78      0.78      0.78        36
# weighted avg       0.78      0.78      0.78        36
#
# Confusion Matrix : [16  4  4 12]
# ...

# %%
# cross val score:
UserCrossValScores(svm_3, X_rus, y_rus, scoring = "recall")
# Out:
# Scores : [0.53846154 0.84615385 0.92307692 1.         0.84615385]
# Mean score : 0.8307692307692307
# Standard Dev. : 0.15689290811054724

# %%
# Ploting Learning Curve:
plt.figure(figsize = (19, 13))

plt.subplot(2, 2, 1)
UserLearningCurve(svm_1, X_train_transformed, y_train, label = "Imbalanced",scoring = "recall")
plt.subplot(2, 2, 2)
UserLearningCurve(svm_2, X_smote, y_smote, label = "SMOTE", scoring = "recall")
plt.subplot(2, 2, 3)
UserLearningCurve(svm_3, X_rus, y_rus, label = "RUS", scoring = "recall")

# %%
# Ploting ROC AUC:
plt.figure(figsize = (10, 6))
plt.plot([0,1], [0,1], "--",label = "Baseline")
UserRocAuc(y_test, y_pred_proba_svm_1, label = "Imbalanced")
UserRocAuc(y_test, y_pred_proba_svm_2, label = "SMOTE")
UserRocAuc(y_test, y_pred_proba_svm_3, label = "RUS")

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# From the above scores, ROC curves and AUC values, SVC with SMOTE is giving slightly highere AUC score. We are going with SMOTE.

# %% [markdown]
# ## Hyperparameter Tuning:

# %%
# %%time
svc_params = {
    "C" : np.linspace(0.0001, 1, 10),
    "kernel" : ["linear", "rbf", "sigmoid"],
    "gamma" : [0.001, 0.01, 0.1, 1, 10, 20,100]
}

UserGridSearchCV(model = SVC(), params = svc_params, X = X_rus, y = y_rus, scoring = "recall")
# Out:
# Best Params : {'C': 1.0, 'gamma': 1, 'kernel': 'rbf'}
# Best Score : 0.9230769230769231
# Best Estimator : SVC(gamma=1)
# CPU times: total: 578 ms
# Wall time: 1.01 s
# SVC(gamma=1)

# %% [markdown]
# ### Fitting the model with optimal parameter

# %%
svc_model = SVC(C=0.11120000000000001, gamma=0.1, probability = True)
svc_model.fit(X_rus, y_rus)
# Out:
# SVC(C=0.11120000000000001, gamma=0.1, probability=True)

# %%
y_hat_train_svc = svc_model.predict(X_rus)
y_hat_test_svc = svc_model.predict(X_test_transformed)
y_hat_prob_svc = svc_model.predict_proba(X_test_transformed)

# %%
UserMetric(y_rus, y_hat_train_svc, label = "Train")
UserMetric(y_test, y_hat_test_svc, label = "Test")
# Out:
# Train:
# Accuracy : 0.84375
# Precision : 0.8333333333333334
# Recall : 0.859375
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        64
#            1       0.83      0.86      0.85        64
#
#     accuracy                           0.84       128
#    macro avg       0.84      0.84      0.84       128
# weighted avg       0.84      0.84      0.84       128
#
# Confusion Matrix : [53 11  9 55]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.7777777777777778
# Recall : 0.875
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        20
#            1       0.78      0.88      0.82        16
#
#     accuracy                           0.83        36
#    macro avg       0.83      0.84      0.83        36
# weighted avg       0.84      0.83      0.83        36
#
# ...

# %%
UserCrossValScores(svc_model, X_rus, y_rus, cv = StratifiedKFold(5), scoring = "recall")
# Out:
# Scores : [0.53846154 0.84615385 0.92307692 1.         0.84615385]
# Mean score : 0.8307692307692307
# Standard Dev. : 0.15689290811054724

# %%
plt.plot([0,1], [0,1], "--", label = "Baseline")
UserRocAuc(y_test, y_hat_prob_svc, label = "RUS")

# %%
plt.figure(figsize = (10,6))
precision, recall, thresholds = precision_recall_curve(y_test, y_hat_prob_svc[:, 1])
plt.plot(recall, precision, label = "SVC")
plt.plot([0,1], [1,1], label = "Perfect model", color = "red", linestyle = 'dotted')
plt.plot([0,1], [0,0], "--",label = "No skill")
plt.title("PR Curve")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ## 4. Decision Tree

# %%
dtree_1 = DecisionTreeClassifier()
dtree_1.fit(X_train_transformed, y_train)

dtree_2 = DecisionTreeClassifier()
dtree_2.fit(X_smote, y_smote)

dtree_3 = DecisionTreeClassifier()
dtree_3.fit(X_rus, y_rus)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_train_dtree_1 = dtree_1.predict(X_train_transformed)
y_pred_test_dtree_1 = dtree_1.predict(X_test_transformed)
y_pred_proba_dtree_1 = dtree_1.predict_proba(X_test_transformed)

y_pred_train_dtree_2 = dtree_2.predict(X_smote)
y_pred_test_dtree_2 = dtree_2.predict(X_test_transformed)
y_pred_proba_dtree_2 = dtree_2.predict_proba(X_test_transformed)

y_pred_train_dtree_3 = dtree_3.predict(X_rus)
y_pred_test_dtree_3 = dtree_3.predict(X_test_transformed)
y_pred_proba_dtree_3 = dtree_3.predict_proba(X_test_transformed)
# Imbalanced:
UserMetric(y_train, y_pred_train_dtree_1, label = "Train")
UserMetric(y_test, y_pred_test_dtree_1, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        64
#
#     accuracy                           1.00       144
#    macro avg       1.00      1.00      1.00       144
# weighted avg       1.00      1.00      1.00       144
#
# Confusion Matrix : [80  0  0 64]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.6944444444444444
# Precision : 0.6666666666666666
# Recall : 0.625
#               precision    recall  f1-score   support
#
#            0       0.71      0.75      0.73        20
#            1       0.67      0.62      0.65        16
#
#     accuracy                           0.69        36
#    macro avg       0.69      0.69      0.69        36
# weighted avg       0.69      0.69      0.69        36
#
# Confusion Matrix : [15  5  6 10]
# ...

# %%
# cross val score:
UserCrossValScores(dtree_1, X_train_transformed, y_train, scoring = "recall")
# Out:
# Scores : [0.53846154 0.76923077 0.76923077 0.76923077 0.75      ]
# Mean score : 0.7192307692307692
# Standard Dev. : 0.09069097017347383

# %%
# Oversampling:
UserMetric(y_smote, y_pred_train_svm_2, label = "Train")
UserMetric(y_test, y_pred_test_svm_2, label = "Test")
# Out:
# Train:
# Accuracy : 0.91875
# Precision : 0.935064935064935
# Recall : 0.9
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        80
#            1       0.94      0.90      0.92        80
#
#     accuracy                           0.92       160
#    macro avg       0.92      0.92      0.92       160
# weighted avg       0.92      0.92      0.92       160
#
# Confusion Matrix : [75  5  8 72]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.8571428571428571
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86        20
#            1       0.86      0.75      0.80        16
#
#     accuracy                           0.83        36
#    macro avg       0.84      0.82      0.83        36
# weighted avg       0.84      0.83      0.83        36
#
# ...

# %%
# cross val score:
UserCrossValScores(svm_2, X_smote, y_smote, scoring = "recall")
# Out:
# Scores : [0.4375 0.9375 0.9375 0.875  0.9375]
# Mean score : 0.825
# Standard Dev. : 0.19525624189766635

# %%
# Undersampling:
UserMetric(y_rus, y_pred_train_svm_3, label = "Train")
UserMetric(y_test, y_pred_test_svm_3, label = "Test")
# Out:
# Train:
# Accuracy : 0.8984375
# Precision : 0.9180327868852459
# Recall : 0.875
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        64
#            1       0.92      0.88      0.90        64
#
#     accuracy                           0.90       128
#    macro avg       0.90      0.90      0.90       128
# weighted avg       0.90      0.90      0.90       128
#
# Confusion Matrix : [59  5  8 56]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.7777777777777778
# Precision : 0.75
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        20
#            1       0.75      0.75      0.75        16
#
#     accuracy                           0.78        36
#    macro avg       0.78      0.78      0.78        36
# weighted avg       0.78      0.78      0.78        36
#
# Confusion Matrix : [16  4  4 12]
# ...

# %%
# cross val score:
UserCrossValScores(svm_3, X_rus, y_rus, scoring = "recall")
# Out:
# Scores : [0.53846154 0.84615385 0.92307692 1.         0.84615385]
# Mean score : 0.8307692307692307
# Standard Dev. : 0.15689290811054724

# %%
# Ploting Learning Curve:
plt.figure(figsize = (19, 13))

plt.subplot(2, 2, 1)
UserLearningCurve(dtree_1, X_train_transformed, y_train, label = "Imbalanced",scoring = "recall")
plt.subplot(2, 2, 2)
UserLearningCurve(dtree_2, X_smote, y_smote, label = "SMOTE", scoring = "recall")
plt.subplot(2, 2, 3)
UserLearningCurve(dtree_3, X_rus, y_rus, label = "RUS", scoring = "recall")

# %%
# Ploting ROC AUC:
plt.figure(figsize = (10, 6))
plt.plot([0,1], [0,1], "--",label = "Baseline")
UserRocAuc(y_test, y_pred_proba_dtree_1, label = "Imbalanced")
UserRocAuc(y_test, y_pred_proba_dtree_2, label = "SMOTE")
UserRocAuc(y_test, y_pred_proba_dtree_3, label = "RUS")

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# ##### From the above scores, ROC curves and AUC values, DTree with RandomUnderSampler is giving slightly highere AUC score. We are going with RandomUnderSampler.

# %% [markdown]
# #### Hyperparameter Tuning:

# %%
# %%time
dtree_params = {
    "criterion" : ["gini", "entropy"],
    "splitter" : ["best", "random"],
    "max_depth" : [1,2,3,4,5,6,7,8],
    "min_samples_split" : [int(x) for x in np.linspace(10,100, 20)]
}

UserGridSearchCV(model = DecisionTreeClassifier(), params = dtree_params, X = X_rus, y = y_rus, scoring = "recall")
# Out:
# Best Params : {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 19, 'splitter': 'random'}
# Best Score : 0.8769230769230768
# Best Estimator : DecisionTreeClassifier(max_depth=5, min_samples_split=19, splitter='random')
# CPU times: total: 1.27 s
# Wall time: 2.24 s
# DecisionTreeClassifier(max_depth=5, min_samples_split=19, splitter='random')

# %% [markdown]
# #### Fitting the model with optimal parameters

# %%
dtree_model = DecisionTreeClassifier(max_depth=5, min_samples_split=38, splitter='random')
dtree_model.fit(X_rus, y_rus)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=38, splitter='random')

# %%
y_hat_train_dtree = dtree_model.predict(X_rus)
y_hat_test_dtree = dtree_model.predict(X_test_transformed)
y_hat_prob_dtree = dtree_model.predict_proba(X_test_transformed)

# %%
UserMetric(y_rus, y_hat_train_dtree, label = "Train")
UserMetric(y_test, y_hat_test_dtree, label = "Test")
# Out:
# Train:
# Accuracy : 0.8125
# Precision : 0.803030303030303
# Recall : 0.828125
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        64
#            1       0.80      0.83      0.82        64
#
#     accuracy                           0.81       128
#    macro avg       0.81      0.81      0.81       128
# weighted avg       0.81      0.81      0.81       128
#
# Confusion Matrix : [51 13 11 53]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.7777777777777778
# Precision : 0.7857142857142857
# Recall : 0.6875
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81        20
#            1       0.79      0.69      0.73        16
#
#     accuracy                           0.78        36
#    macro avg       0.78      0.77      0.77        36
# weighted avg       0.78      0.78      0.78        36
#
# ...

# %%
UserCrossValScores(dtree_model, X_rus, y_rus, cv = StratifiedKFold(5), scoring = "recall")
# Out:
# Scores : [0.69230769 0.84615385 0.92307692 0.91666667 0.69230769]
# Mean score : 0.8141025641025641
# Standard Dev. : 0.10304375024312884

# %%
plt.plot([0,1], [0,1], "--", label = "Baseline")
UserRocAuc(y_test, y_hat_prob_dtree, label = "RUS")

# %%
plt.figure(figsize = (10,6))
precision, recall, thresholds = precision_recall_curve(y_test, y_hat_prob_dtree[:, 1])
plt.plot(recall, precision, label = "DTree")
plt.plot([0,1], [1,1], label = "Perfect model", color = "red", linestyle = 'dotted')
plt.plot([0,1], [0,0], "--",label = "No skill")
plt.title("PR Curve")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ## RESULT 4:

# %% [markdown]
# From the above scores, ROC curves, AUC values and PR curve, SVC with RandomUnderSampler is performing well from the rest sampling techniques.

# %% [markdown]
# ## 5. MLPC

# %%
mlpc_1 = MLPClassifier()
mlpc_1.fit(X_train_transformed, y_train)

mlpc_2 = MLPClassifier()
mlpc_2.fit(X_smote, y_smote)

mlpc_3 = MLPClassifier()
mlpc_3.fit(X_rus, y_rus)
# Out:
# MLPClassifier()

# %%
y_pred_train_mlpc_1 = mlpc_1.predict(X_train_transformed)
y_pred_test_mlpc_1 = mlpc_1.predict(X_test_transformed)
y_pred_proba_mlpc_1 = mlpc_1.predict_proba(X_test_transformed)

y_pred_train_mlpc_2 = mlpc_2.predict(X_smote)
y_pred_test_mlpc_2 = mlpc_2.predict(X_test_transformed)
y_pred_proba_mlpc_2 = mlpc_2.predict_proba(X_test_transformed)

y_pred_train_mlpc_3 = mlpc_3.predict(X_rus)
y_pred_test_mlpc_3 = mlpc_3.predict(X_test_transformed)
y_pred_proba_mlpc_3 = mlpc_3.predict_proba(X_test_transformed)

# %%
# Imbalanced:
UserMetric(y_train, y_pred_train_mlpc_1, label = "Train")
UserMetric(y_test, y_pred_test_mlpc_1, label = "Test")
# Out:
# Train:
# Accuracy : 0.9375
# Precision : 0.9661016949152542
# Recall : 0.890625
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95        80
#            1       0.97      0.89      0.93        64
#
#     accuracy                           0.94       144
#    macro avg       0.94      0.93      0.94       144
# weighted avg       0.94      0.94      0.94       144
#
# Confusion Matrix : [78  2  7 57]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8055555555555556
# Precision : 0.8461538461538461
# Recall : 0.6875
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        20
#            1       0.85      0.69      0.76        16
#
#     accuracy                           0.81        36
#    macro avg       0.81      0.79      0.80        36
# weighted avg       0.81      0.81      0.80        36
#
# ...

# %%
# cross val score:
UserCrossValScores(mlpc_1, X_train_transformed, y_train, scoring = "recall")
# Out:
# Scores : [0.30769231 0.84615385 0.76923077 0.84615385 0.75      ]
# Mean score : 0.7038461538461538
# Standard Dev. : 0.20191391920625673

# %%
# Oversampling:
UserMetric(y_smote, y_pred_train_mlpc_2, label = "Train")
UserMetric(y_test, y_pred_test_mlpc_2, label = "Test")
# Out:
# Train:
# Accuracy : 0.95625
# Precision : 0.974025974025974
# Recall : 0.9375
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        80
#            1       0.97      0.94      0.96        80
#
#     accuracy                           0.96       160
#    macro avg       0.96      0.96      0.96       160
# weighted avg       0.96      0.96      0.96       160
#
# Confusion Matrix : [78  2  5 75]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.8571428571428571
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86        20
#            1       0.86      0.75      0.80        16
#
#     accuracy                           0.83        36
#    macro avg       0.84      0.82      0.83        36
# weighted avg       0.84      0.83      0.83        36
#
# ...

# %%
# cross val score:
UserCrossValScores(mlpc_2, X_smote, y_smote, scoring = "recall")
# Out:
# Scores : [0.5625 1.     0.875  0.8125 0.9375]
# Mean score : 0.8375
# Standard Dev. : 0.15103807466993216

# %%
# Undersampling:
UserMetric(y_rus, y_pred_train_mlpc_3, label = "Train")
UserMetric(y_test, y_pred_test_mlpc_3, label = "Test")
# Out:
# Train:
# Accuracy : 0.9296875
# Precision : 0.9661016949152542
# Recall : 0.890625
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93        64
#            1       0.97      0.89      0.93        64
#
#     accuracy                           0.93       128
#    macro avg       0.93      0.93      0.93       128
# weighted avg       0.93      0.93      0.93       128
#
# Confusion Matrix : [62  2  7 57]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8055555555555556
# Precision : 0.8
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        20
#            1       0.80      0.75      0.77        16
#
#     accuracy                           0.81        36
#    macro avg       0.80      0.80      0.80        36
# weighted avg       0.81      0.81      0.80        36
#
# Confusion Matrix : [17  3  4 12]
# ...

# %%
# cross val score:
UserCrossValScores(mlpc_3, X_rus, y_rus, scoring = "recall")
# Out:
# Scores : [0.46153846 0.76923077 0.84615385 1.         0.76923077]
# Mean score : 0.7692307692307693
# Standard Dev. : 0.17541160386140583

# %%
# Ploting Learning Curve:
plt.figure(figsize = (19, 13))

plt.subplot(2, 2, 1)
UserLearningCurve(mlpc_1, X_train_transformed, y_train, label = "Imbalanced",scoring = "recall")
plt.subplot(2, 2, 2)
UserLearningCurve(mlpc_2, X_smote, y_smote, label = "SMOTE", scoring = "recall")
plt.subplot(2, 2, 3)
UserLearningCurve(mlpc_3, X_rus, y_rus, label = "RUS", scoring = "recall")

# %%
# Ploting ROC AUC:
plt.figure(figsize = (10, 6))
plt.plot([0,1], [0,1], "--",label = "Baseline")
UserRocAuc(y_test, y_pred_proba_mlpc_1, label = "Imbalanced")
UserRocAuc(y_test, y_pred_proba_mlpc_2, label = "SMOTE")
UserRocAuc(y_test, y_pred_proba_mlpc_3, label = "RUS")

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# #### From the above scores, ROC curves and AUC values, MLPC with RandomUnderSampler is giving slightly highere AUC score. We are going with RandomUnderSampler.

# %% [markdown]
# #### Hyperparameter Tuning:

# %%
# %%time
mlpc_params = {
    "hidden_layer_sizes" : [int(x) for x in np.linspace(100, 500, 5)],
    "activation" : ["relu", "logistic", "tanh"],
    "solver" : ['lbfgs','sgd','adam'],
    "learning_rate_init" : np.linspace(0.0001, 0.1, 10)
}

UserGridSearchCV(model = MLPClassifier(), params = mlpc_params, X = X_rus, y = y_rus, scoring = "recall")
# Out:
# Best Params : {'activation': 'logistic', 'hidden_layer_sizes': 200, 'learning_rate_init': 0.0889, 'solver': 'lbfgs'}
# Best Score : 0.8615384615384615
# Best Estimator : MLPClassifier(activation='logistic', hidden_layer_sizes=200,
#               learning_rate_init=0.0889, solver='lbfgs')
# CPU times: total: 7.7 s
# Wall time: 1min 34s
# MLPClassifier(activation='logistic', hidden_layer_sizes=200,
#               learning_rate_init=0.0889, solver='lbfgs')

# %% [markdown]
# #### Fitting the model with optimal parameters

# %%
mlpc_model = MLPClassifier(activation='logistic', hidden_layer_sizes=400, learning_rate_init=0.06670000000000001, solver='sgd')
mlpc_model.fit(X_rus, y_rus)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=400,
#               learning_rate_init=0.06670000000000001, solver='sgd')

# %%
y_hat_train_mlpc = mlpc_model.predict(X_rus)
y_hat_test_mlpc = mlpc_model.predict(X_test_transformed)
y_hat_prob_mlpc = mlpc_model.predict_proba(X_test_transformed)

# %%
UserMetric(y_rus, y_hat_train_mlpc, label = "Train")
UserMetric(y_test, y_hat_test_mlpc, label = "Test")
# Out:
# Train:
# Accuracy : 0.5
# Precision : 0.5
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        64
#            1       0.50      1.00      0.67        64
#
#     accuracy                           0.50       128
#    macro avg       0.25      0.50      0.33       128
# weighted avg       0.25      0.50      0.33       128
#
# Confusion Matrix : [ 0 64  0 64]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.4444444444444444
# Precision : 0.4444444444444444
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        20
#            1       0.44      1.00      0.62        16
#
#     accuracy                           0.44        36
#    macro avg       0.22      0.50      0.31        36
# weighted avg       0.20      0.44      0.27        36
#
# Confusion Matrix : [ 0 20  0 16]
# ...

# %%
UserCrossValScores(mlpc_model, X_rus, y_rus, cv = StratifiedKFold(10), scoring = "recall")
# Out:
# Scores : [0. 1. 1. 1. 0. 1. 0. 0. 1. 1.]
# Mean score : 0.6
# Standard Dev. : 0.48989794855663565

# %%
plt.plot([0,1], [0,1], "--", label = "Baseline")
UserRocAuc(y_test, y_hat_prob_mlpc, label = "RUS")

# %%
plt.figure(figsize = (10,6))
precision, recall, thresholds = precision_recall_curve(y_test, y_hat_prob_mlpc[:, 1])
plt.plot(recall, precision, label = "MLPC")
plt.plot([0,1], [1,1], label = "Perfect model", color = "red", linestyle = 'dotted')
plt.plot([0,1], [0,0], "--",label = "No skill")
plt.title("PR Curve")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ## RESULT 5:

# %% [markdown]
# From the above recall scores, ROC curves, AUC values and PR curve, MLPC with RandomUnderSampler has predicted 0 positive classes and has 0 FN.

# %% [markdown]
# ## 6. RandomForest

# %%
rf_1 = RandomForestClassifier()
rf_1.fit(X_train_transformed, y_train)

rf_2 = RandomForestClassifier()
rf_2.fit(X_smote, y_smote)

rf_3 = RandomForestClassifier()
rf_3.fit(X_rus, y_rus)
# Out:
# RandomForestClassifier()

# %%
y_pred_train_rf_1 = rf_1.predict(X_train_transformed)
y_pred_test_rf_1 = rf_1.predict(X_test_transformed)
y_pred_proba_rf_1 = rf_1.predict_proba(X_test_transformed)

y_pred_train_rf_2 = rf_2.predict(X_smote)
y_pred_test_rf_2 = rf_2.predict(X_test_transformed)
y_pred_proba_rf_2 = rf_2.predict_proba(X_test_transformed)

y_pred_train_rf_3 = rf_3.predict(X_rus)
y_pred_test_rf_3 = rf_3.predict(X_test_transformed)
y_pred_proba_rf_3 = rf_3.predict_proba(X_test_transformed)

# %%
# Imbalanced:
UserMetric(y_train, y_pred_train_rf_1, label = "Train")
UserMetric(y_test, y_pred_test_rf_1, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        64
#
#     accuracy                           1.00       144
#    macro avg       1.00      1.00      1.00       144
# weighted avg       1.00      1.00      1.00       144
#
# Confusion Matrix : [80  0  0 64]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.8125
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        20
#            1       0.81      0.81      0.81        16
#
#     accuracy                           0.83        36
#    macro avg       0.83      0.83      0.83        36
# weighted avg       0.83      0.83      0.83        36
#
# Confusion Matrix : [17  3  3 13]
# ...

# %%
# cross val score:
UserCrossValScores(rf_1, X_train_transformed, y_train, scoring = "recall")
# Out:
# Scores : [0.53846154 0.76923077 0.84615385 0.84615385 0.75      ]
# Mean score : 0.75
# Standard Dev. : 0.11279137152780909

# %%
# Oversampling:
UserMetric(y_smote, y_pred_train_rf_2, label = "Train")
UserMetric(y_test, y_pred_test_rf_2, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160
#
# Confusion Matrix : [80  0  0 80]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8055555555555556
# Precision : 0.8
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        20
#            1       0.80      0.75      0.77        16
#
#     accuracy                           0.81        36
#    macro avg       0.80      0.80      0.80        36
# weighted avg       0.81      0.81      0.80        36
#
# Confusion Matrix : [17  3  4 12]
# ...

# %%
# cross val score:
UserCrossValScores(rf_2, X_smote, y_smote, scoring = "recall")
# Out:
# Scores : [0.5    0.9375 1.     0.8125 1.    ]
# Mean score : 0.85
# Standard Dev. : 0.18791620472966136

# %%
# Undersampling:
UserMetric(y_rus, y_pred_train_rf_3, label = "Train")
UserMetric(y_test, y_pred_test_rf_3, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        64
#            1       1.00      1.00      1.00        64
#
#     accuracy                           1.00       128
#    macro avg       1.00      1.00      1.00       128
# weighted avg       1.00      1.00      1.00       128
#
# Confusion Matrix : [64  0  0 64]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.8125
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        20
#            1       0.81      0.81      0.81        16
#
#     accuracy                           0.83        36
#    macro avg       0.83      0.83      0.83        36
# weighted avg       0.83      0.83      0.83        36
#
# Confusion Matrix : [17  3  3 13]
# ...

# %%
# cross val score:
UserCrossValScores(rf_3, X_rus, y_rus, scoring = "recall")
# Out:
# Scores : [0.53846154 0.84615385 0.84615385 0.91666667 0.76923077]
# Mean score : 0.7833333333333333
# Standard Dev. : 0.13102037221580734

# %%
# Ploting Learning Curve:
plt.figure(figsize = (19, 13))

plt.subplot(2, 2, 1)
UserLearningCurve(rf_1, X_train_transformed, y_train, label = "Imbalanced",scoring = "recall")
plt.subplot(2, 2, 2)
UserLearningCurve(rf_2, X_smote, y_smote, label = "SMOTE", scoring = "recall")
plt.subplot(2, 2, 3)
UserLearningCurve(rf_3, X_rus, y_rus, label = "RUS", scoring = "recall")

# %%
# Ploting ROC AUC:
plt.figure(figsize = (10, 6))
plt.plot([0,1], [0,1], "--",label = "Baseline")
UserRocAuc(y_test, y_pred_proba_rf_1, label = "Imbalanced")
UserRocAuc(y_test, y_pred_proba_rf_2, label = "SMOTE")
UserRocAuc(y_test, y_pred_proba_rf_3, label = "RUS")

# %% [markdown]
# ### Conclusion:
# From the above scores, ROC curves and AUC values, RandomForest with SMOTE oversampling is giving slightly higher AUC score.

# %% [markdown]
# ### Hyperparameter Tuning:

# %%
# %%time
rf_params = {
    "n_estimators" : [int(x) for x in np.linspace(100, 500, 5)],
    "criterion" : ["gini", "entropy"],
    "max_depth" : [3,4,5,6,7,8],
    "min_samples_split" : [int(x) for x in np.linspace(10, 100, 5)],
}

UserGridSearchCV(model = RandomForestClassifier(), params = rf_params, X = X_smote, y = y_smote, scoring = "recall")
# Out:
# Best Params : {'criterion': 'entropy', 'max_depth': 4, 'min_samples_split': 100, 'n_estimators': 300}
# Best Score : 1.0
# Best Estimator : RandomForestClassifier(criterion='entropy', max_depth=4, min_samples_split=100,
#                        n_estimators=300)
# CPU times: total: 5.8 s
# Wall time: 5min 24s
# RandomForestClassifier(criterion='entropy', max_depth=4, min_samples_split=100,
#                        n_estimators=300)

# %% [markdown]
# #### Fitting the model with optimal parameters

# %%
rf_model = RandomForestClassifier(max_depth=3, min_samples_split=100, n_estimators=200)
rf_model.fit(X_smote, y_smote)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_split=100, n_estimators=200)

# %%
y_hat_train_rf = rf_model.predict(X_smote)
y_hat_test_rf = rf_model.predict(X_test_transformed)
y_hat_prob_rf = rf_model.predict_proba(X_test_transformed)

# %%
UserMetric(y_smote, y_hat_train_rf, label = "Train")
UserMetric(y_test, y_hat_test_rf, label = "Test")
# Out:
# Train:
# Accuracy : 0.83125
# Precision : 0.8354430379746836
# Recall : 0.825
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83        80
#            1       0.84      0.82      0.83        80
#
#     accuracy                           0.83       160
#    macro avg       0.83      0.83      0.83       160
# weighted avg       0.83      0.83      0.83       160
#
# Confusion Matrix : [67 13 14 66]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.8571428571428571
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86        20
#            1       0.86      0.75      0.80        16
#
#     accuracy                           0.83        36
#    macro avg       0.84      0.82      0.83        36
# weighted avg       0.84      0.83      0.83        36
#
# ...

# %%
UserCrossValScores(rf_model, X_smote, y_smote, cv = StratifiedKFold(10), scoring = "recall")
# Out:
# Scores : [1.    1.    0.    1.    1.    0.5   0.625 0.    0.625 0.   ]
# Mean score : 0.575
# Standard Dev. : 0.4153311931459037

# %%
plt.plot([0,1], [0,1], "--", label = "Baseline")
UserRocAuc(y_test, y_hat_prob_rf, label = "RUS")

# %%
plt.figure(figsize = (10,6))
precision, recall, thresholds = precision_recall_curve(y_test, y_hat_prob_rf[:, 1])
plt.plot(recall, precision, label = "RandomForest")
plt.plot([0,1], [1,1], label = "Perfect model", color = "red", linestyle = 'dotted')
plt.plot([0,1], [0,0], "--",label = "No skill")
plt.title("PR Curve")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# #### RESULT 6:
# From the above scores, ROC curves, AUC values and PR curve, RandomForest with SMOTE is performing well from the rest sampling techniques.

# %% [markdown]
# ## 7. XGBoost

# %%
xgb_1 = XGBClassifier()
xgb_1.fit(X_train_transformed, y_train)

xgb_2 = XGBClassifier()
xgb_2.fit(X_smote, y_smote)

xgb_3 = XGBClassifier()
xgb_3.fit(X_rus, y_rus)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred_train_xgb_1 = xgb_1.predict(X_train_transformed)
y_pred_test_xgb_1 = xgb_1.predict(X_test_transformed)
y_pred_proba_xgb_1 = xgb_1.predict_proba(X_test_transformed)

y_pred_train_xgb_2 = xgb_2.predict(X_smote)
y_pred_test_xgb_2 = xgb_2.predict(X_test_transformed)
y_pred_proba_xgb_2 = xgb_2.predict_proba(X_test_transformed)

y_pred_train_xgb_3 = xgb_3.predict(X_rus)
y_pred_test_xgb_3 = xgb_3.predict(X_test_transformed)
y_pred_proba_xgb_3 = xgb_3.predict_proba(X_test_transformed)

# %%
# Imbalanced:
UserMetric(y_train, y_pred_train_xgb_1, label = "Train")
UserMetric(y_test, y_pred_test_xgb_1, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        64
#
#     accuracy                           1.00       144
#    macro avg       1.00      1.00      1.00       144
# weighted avg       1.00      1.00      1.00       144
#
# Confusion Matrix : [80  0  0 64]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.75
# Precision : 0.7058823529411765
# Recall : 0.75
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        20
#            1       0.71      0.75      0.73        16
#
#     accuracy                           0.75        36
#    macro avg       0.75      0.75      0.75        36
# weighted avg       0.75      0.75      0.75        36
#
# Confusion Matrix : [15  5  4 12]
# ...

# %%
# cross val score:
UserCrossValScores(xgb_1, X_train_transformed, y_train, scoring = "recall")
# Out:
# Scores : [0.46153846 0.76923077 0.84615385 0.84615385 0.83333333]
# Mean score : 0.7512820512820514
# Standard Dev. : 0.14765312870654326

# %%
# Oversampling:
UserMetric(y_smote, y_pred_train_xgb_2, label = "Train")
UserMetric(y_test, y_pred_test_xgb_2, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        80
#
#     accuracy                           1.00       160
#    macro avg       1.00      1.00      1.00       160
# weighted avg       1.00      1.00      1.00       160
#
# Confusion Matrix : [80  0  0 80]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.7777777777777778
# Recall : 0.875
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        20
#            1       0.78      0.88      0.82        16
#
#     accuracy                           0.83        36
#    macro avg       0.83      0.84      0.83        36
# weighted avg       0.84      0.83      0.83        36
#
# Confusion Matrix : [16  4  2 14]
# ...

# %%
# cross val score:
UserCrossValScores(xgb_2, X_smote, y_smote, scoring = "recall")
# Out:
# Scores : [0.5625 0.875  0.875  0.75   0.875 ]
# Mean score : 0.7875
# Standard Dev. : 0.1224744871391589

# %%
# Undersampling:
UserMetric(y_rus, y_pred_train_xgb_3, label = "Train")
UserMetric(y_test, y_pred_test_xgb_3, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        64
#            1       1.00      1.00      1.00        64
#
#     accuracy                           1.00       128
#    macro avg       1.00      1.00      1.00       128
# weighted avg       1.00      1.00      1.00       128
#
# Confusion Matrix : [64  0  0 64]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.8333333333333334
# Precision : 0.8125
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        20
#            1       0.81      0.81      0.81        16
#
#     accuracy                           0.83        36
#    macro avg       0.83      0.83      0.83        36
# weighted avg       0.83      0.83      0.83        36
#
# Confusion Matrix : [17  3  3 13]
# ...

# %%
# cross val score:
UserCrossValScores(xgb_3, X_rus, y_rus, scoring = "recall")
# Out:
# Scores : [0.46153846 0.84615385 0.84615385 0.83333333 0.69230769]
# Mean score : 0.735897435897436
# Standard Dev. : 0.1489829645777841

# %%
# Ploting Learning Curve:
plt.figure(figsize = (19, 13))

plt.subplot(2, 2, 1)
UserLearningCurve(xgb_1, X_train_transformed, y_train, label = "Imbalanced",scoring = "recall")
plt.subplot(2, 2, 2)
UserLearningCurve(xgb_2, X_smote, y_smote, label = "SMOTE", scoring = "recall")
plt.subplot(2, 2, 3)
UserLearningCurve(xgb_3, X_rus, y_rus, label = "RUS", scoring = "recall")

# %%
# Ploting ROC AUC:
plt.figure(figsize = (10, 6))
plt.plot([0,1], [0,1], "--",label = "Baseline")
UserRocAuc(y_test, y_pred_proba_xgb_1, label = "Imbalanced")
UserRocAuc(y_test, y_pred_proba_xgb_2, label = "SMOTE")
UserRocAuc(y_test, y_pred_proba_xgb_3, label = "RUS")

# %% [markdown]
# ### Conclusion:
# From the above scores, ROC curves and AUC values, SVC with RandomUnderSampler is giving slightly highere AUC score. We are going with RandomUnderSampler.

# %% [markdown]
# ## Hyperparameter Tuning:

# %%
# %%time
xgb_params = {
    "learning_rate" : np.linspace(0.001, 0.1, 6),
    "max_depth" : [3,4,5,6,7],
    "n_estimators" : [int(x) for x in np.linspace(100, 500, 5)],
    "gamma" : np.linspace(0.0001, 0.1, 4)
}

UserGridSearchCV(model = XGBClassifier(), params = xgb_params, X = X_rus, y = y_rus, cv = 3,scoring = "recall")
# Out:
# Best Params : {'gamma': 0.0001, 'learning_rate': 0.06040000000000001, 'max_depth': 5, 'n_estimators': 300}
# Best Score : 0.7950937950937952
# Best Estimator : XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.0001, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.06040000000000001,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
# CPU times: total: 9.14 s
# Wall time: 47 s
# ...

# %% [markdown]
# #### Fitting the model with optimal parameters

# %%
xgb_model = XGBClassifier(gamma = 0.0001, learning_rate = 0.020800000000000003, max_depth = 3, n_estimators = 500)
xgb_model.fit(X_rus, y_rus)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.0001, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.020800000000000003,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_hat_train_xgb = xgb_model.predict(X_rus)
y_hat_test_xgb = xgb_model.predict(X_test_transformed)
y_hat_prob_xgb = xgb_model.predict_proba(X_test_transformed)

# %%
UserMetric(y_rus, y_hat_train_xgb, label = "Train")
UserMetric(y_test, y_hat_test_xgb, label = "Test")
# Out:
# Train:
# Accuracy : 1.0
# Precision : 1.0
# Recall : 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        64
#            1       1.00      1.00      1.00        64
#
#     accuracy                           1.00       128
#    macro avg       1.00      1.00      1.00       128
# weighted avg       1.00      1.00      1.00       128
#
# Confusion Matrix : [64  0  0 64]
# --------------------------------------------------------------------------------
# Test:
# Accuracy : 0.7777777777777778
# Precision : 0.7222222222222222
# Recall : 0.8125
#               precision    recall  f1-score   support
#
#            0       0.83      0.75      0.79        20
#            1       0.72      0.81      0.76        16
#
#     accuracy                           0.78        36
#    macro avg       0.78      0.78      0.78        36
# weighted avg       0.78      0.78      0.78        36
#
# Confusion Matrix : [15  5  3 13]
# ...

# %%
UserCrossValScores(xgb_model, X_rus, y_rus, cv = StratifiedKFold(5), scoring = "recall")
# Out:
# Scores : [0.53846154 0.84615385 0.84615385 0.91666667 0.69230769]
# Mean score : 0.7679487179487179
# Standard Dev. : 0.13618740230655899

# %%
plt.plot([0,1], [0,1], "--", label = "Baseline")
UserRocAuc(y_test, y_hat_prob_xgb, label = "RUS")

# %%
plt.figure(figsize = (10,6))
precision, recall, thresholds = precision_recall_curve(y_test, y_hat_prob_xgb[:, 1])
plt.plot(recall, precision, label = "XGBoost")
plt.plot([0,1], [1,1], label = "Perfect model", color = "red", linestyle = 'dotted')
plt.plot([0,1], [0,0], "--",label = "No skill")
plt.title("PR Curve")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ### RESULT 7:
# From the above scores, ROC curves, AUC values and PR curve, XGBoost with RandomUnderSampler is performing well from the rest sampling techniques.

# %% [markdown]
# # Creating comparison table like DataFrame

# %%
logReg_dict = [
    {"Model" : "LogisticRegression", "Sampling Technique" : "RandomUnderSampler","Recall" : 0.8125, "FN" : 3},
    {"Model" : "KNeighborsClassifier", "Sampling Technique" : "RandomUnderSampler","Recall" : 0.8125, "FN" : 3},
    {"Model" : "SVC", "Sampling Technique" : "RandomUnderSampler","Recall" : 0.875, "FN" : 2},
    {"Model" : "DecisionTreeClassifier", "Sampling Technique" : "RandomUnderSampler","Recall" : 0.625, "FN" : 6},
    {"Model" : "MLPClassifier", "Sampling Technique" : "RandomUnderSampler","Recall" : 1.0, "FN" : 0},
    {"Model" : "RandomForestClassifier", "Sampling Technique" : "SMOTE","Recall" : 0.75, "FN" : 4},
    {"Model" : "XGBClassifier", "Sampling Technique" : "RandomUnderSampler","Recall" : 0.9375, "FN" : 1}
]

# %%
comparison_df = pd.DataFrame(logReg_dict)
comparison_df
# Out:
#                     Model  Sampling Technique  Recall  FN
# 0      LogisticRegression  RandomUnderSampler  0.8125   3
# 1    KNeighborsClassifier  RandomUnderSampler  0.8125   3
# 2                     SVC  RandomUnderSampler  0.8750   2
# 3  DecisionTreeClassifier  RandomUnderSampler  0.6250   6
# 4           MLPClassifier  RandomUnderSampler  1.0000   0
# 5  RandomForestClassifier               SMOTE  0.7500   4
# 6           XGBClassifier  RandomUnderSampler  0.9375   1

# %%
plt.figure(figsize=(15, 5))
sns.barplot(x="Model", y="Recall", data=comparison_df)
plt.show()

# %% [markdown]
# ### Insight :
# #### Out of all classifers, we observed that the number misclassification in MLPClassifier is 0. But its TP value is also Zero. And XGBoost has misclassifed only 1 prediction, and having recall of 0.9375 which is greater than rest of the classifiers.

# %% [markdown]
# ### Exporting the pipeline and the model in the form of pickle file for our test predictions

# %%
import pickle
#-------------OneHotEncoding, Standardscale and XGBoost Model------------------------

with open("preprocessing1_pipe.pkl", "wb") as f:
    pickle.dump(pipe_1, f)
    
with open("XgbModel1.pkl", "wb") as f:
    pickle.dump(xgb_model, f)

# %% [markdown]
# #### List of all saved pickle files

# %%
# Assuming 'newheartdisease' is a subdirectory in the current directory
directory_path = r'.\newheartdisease'

# Check if the directory exists
if os.path.exists(directory_path) and os.path.isdir(directory_path):
    # List contents of the directory
    for dirname, _, filenames in os.walk(directory_path):
        for filename in filenames:
            print(os.path.join(dirname, filename))
else:
    print("Directory does not exist or is not a valid directory.")
# Out:
# .\newheartdisease\labels.csv
# .\newheartdisease\values.csv

# %% [markdown]
# ### Creating a simple application for prediction

# %%
#---------------Load the model from a directory----------------
with open("preprocessing1_pipe.pkl", "rb") as f:
    preprocessing_steps = pickle.load(f)
    
with open("XgbModel.pkl", "rb") as f:
    XGB_model = pickle.load(f)

# %% [markdown]
# #### Defining a function which will take user data and predict the Probabilty and predicted output if a person is having Heart Disease or not.

# %%
def predict_heart_disease():
    """
    This function return the predicted chances of getting heart disease.
    
    Returns:
        int or float: The Probabilty along with predicted output.
    """
    
    sex = int(input("Enter your gender(0:female, 1:male):"))
    age = int(input("Enter your age:"))
    slope_of_peak = int(input("Enter the type of slope of peak ST segment(1 : upsloping, 2: flat, 3: down sloping):"))
    thal = int(input("Enter the result of thallium stress test measuring blood flow to the heart(1: fixed defect, 2: normal blood flow, 3: reversible defect):"))
    resting_bp = int(input("Enter the blood pressure at rest(mmHg):"))
    cp_type = int(input("Enter the chest pain type(1:typical angina,2:atypical angina,3:non-anginal pain,4:asymptomatic):"))
    major_vessels = int(input("Enter the number major vessels(0 - 3):"))
    fasting_blood_sugar = int(input("Fasting Blood Pressure greater than 120(mg/dl) [Yes(1)/No(0)]:"))
    resting_ekg = int(input("Resting electrocardiographic results(0: normal,1: having ST-T wave abnormality,2: showing probable or definite left ventricular hypertrophy):"))
    serum_cholesterol = float(input("Enter the amount of serum cholestrol(mg/dl):"))
    oldpeak_st_dep = float(input("Enter oldpeak/ST depression(mm):"))
    max_heart_rate = float(input("Enter the maximum heart rate:"))
    ex_induced_angina = int(input("Any chest pain due to exercise[Yes(1)/No(0)]:"))
    
    thal_value = ""
    if thal == 1:
        thal_value = "fixed_defect"
    elif thal == 2:
        thal_value = "normal"
    elif thal == 3:
        thal_value = "reversible_defect"
        
    test_data = [
        slope_of_peak,
        thal_value,
        resting_bp,
        cp_type,
        major_vessels,
        fasting_blood_sugar,
        resting_ekg,
        serum_cholesterol,
        oldpeak_st_dep,
        sex,
        age,
        max_heart_rate,
        ex_induced_angina
    ]
    
    #--------------Encoding, Scaling and Predicting the test data----------------------
    
    preprocessed_value = preprocessing_steps.transform([test_data])
    prediction = XGB_model.predict(preprocessed_value)[0]
    
    if prediction == 0:
        prediction_proba = XGB_model.predict_proba(preprocessed_value)[:, 0]
        print(f"\nNo Heart Disease and Chances are {round((prediction_proba[0]*100), 3)}%")
    elif prediction == 1:
        prediction_proba = XGB_model.predict_proba(preprocessed_value)[:, 1]
        print("\n*************************WARNING**********************************")
        print(f"You have a Heart Disease and Chances are {round((prediction_proba[0]*100), 3)}%")
        print("********************************************************************")

# %%
 predict_heart_disease()
# Out:
# Enter your gender(0:female, 1:male): 0
# Enter your age: 45
# Enter the type of slope of peak ST segment(1 : upsloping, 2: flat, 3: down sloping): 3
# Enter the result of thallium stress test measuring blood flow to the heart(1: fixed defect, 2: normal blood flow, 3: reversible defect): 3
# Enter the blood pressure at rest(mmHg): 14090
# Enter the chest pain type(1:typical angina,2:atypical angina,3:non-anginal pain,4:asymptomatic): 4
# Enter the number major vessels(0 - 3): 2
# Fasting Blood Pressure greater than 120(mg/dl) [Yes(1)/No(0)]: 140
# Resting electrocardiographic results(0: normal,1: having ST-T wave abnormality,2: showing probable or definite left ventricular hypertrophy): 1
# Enter the amount of serum cholestrol(mg/dl): 150
# Enter oldpeak/ST depression(mm): 4
# Enter the maximum heart rate: 160
# Any chest pain due to exercise[Yes(1)/No(0)]: 0
# *************************WARNING**********************************
# You have a Heart Disease and Chances are 98.293%
# ...

# %% [markdown]
# ### Conclusion:
# #### We have choosen XGBoostClassifier for predicting the Heart Disease
